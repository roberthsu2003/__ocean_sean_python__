# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
for i in range(10):
    print(i)

# %%
for i in range(1,11,1):
    print(i)

# %%
for i in range(1, 11, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
